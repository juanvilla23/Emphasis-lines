# %%
import pandas as pd
Datos=pd.read_csv("movies.csv")
Datos.head(5)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %% [markdown]
# Muestra las primeras 5 filas

# %%
import pandas as pd
Datos=pd.read_csv("movies.csv")
Datos.head(5)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %% [markdown]
# Muestra las primeras 10 filas.

# %%
Datos.head(9)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
# 5                          Outer Banks     (2020– )
# 6      The Last Letter from Your Lover       (2021)
# 7                               Dexter  (2006–2013)
# 8                    Never Have I Ever     (2020– )
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
# 5          \nAction, Crime, Drama                 7.6
# 6                \nDrama, Romance                 6.8
# ...

# %% [markdown]
# Ultimas 10 filas

# %%
Datos.tail(10)
# Out:
#                   MOVIES      YEAR  \
# 9989                1899  (2022– )
# 9990                1899  (2022– )
# 9991                1899  (2022– )
# 9992                1899  (2022– )
# 9993           Totenfrau  (2022– )
# 9994      The Imperfects  (2021– )
# 9995              Arcane  (2021– )
# 9996   Heart of Invictus  (2022– )
# 9997      The Imperfects  (2021– )
# 9998      The Imperfects  (2021– )
#
#                                            GENRE  RATING        ONE-LINE  \
# 9989        \nDrama, History, Horror                 NaN  \nAdd a Plot\n
# 9990        \nDrama, History, Horror                 NaN  \nAdd a Plot\n
# 9991        \nDrama, History, Horror                 NaN  \nAdd a Plot\n
# 9992        \nDrama, History, Horror                 NaN  \nAdd a Plot\n
# 9993               \nDrama, Thriller                 NaN  \nAdd a Plot\n
# 9994     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
# ...

# %% [markdown]
# Ultimas 5

# %%
Datos.tail(5)
# Out:
#                   MOVIES      YEAR  \
# 9994      The Imperfects  (2021– )
# 9995              Arcane  (2021– )
# 9996   Heart of Invictus  (2022– )
# 9997      The Imperfects  (2021– )
# 9998      The Imperfects  (2021– )
#
#                                            GENRE  RATING        ONE-LINE  \
# 9994     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
# 9995  \nAnimation, Action, Adventure                 NaN  \nAdd a Plot\n
# 9996            \nDocumentary, Sport                 NaN  \nAdd a Plot\n
# 9997     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
# 9998     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
#
#                                                   STARS VOTES  RunTime Gross
# 9994  \n            \n    Stars:\nMorgan Taylor Camp...   NaN      NaN   NaN
# 9995                                                 \n   NaN      NaN   NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...   NaN      NaN   NaN
# ...

# %% [markdown]
# Cuantas filas y columnas tiene?

# %%
print(Datos.shape)
# Out:
# (9999, 9)

# %% [markdown]
# Convierte df.columns a lista de Python y muestra solo las primeras 3 columnas.

# %%
for col in Datos.columns[:3]:
    print(col)
# Out:
# MOVIES
# YEAR
# GENRE

# %% [markdown]
# Verifica si existe una columna llamada "RATING" usando in.

# %%
if "RATING" in Datos.columns:
    print("La columna RATING existe en el DataFrame.")
# Out:
# La columna RATING existe en el DataFrame.

# %%
Datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   str
#  1   YEAR      9355 non-null   str
#  2   GENRE     9919 non-null   str
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   str
#  5   STARS     9999 non-null   str
#  6   VOTES     8179 non-null   str
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    str
# dtypes: float64(2), str(7)
# memory usage: 703.2 KB

# %%
if "RATING" in Datos.columns:
    print("La columna RATING existe en el DataFrame.")
# Out:
# hola

# %% [markdown]
# imprimir hola

# %%
print("hola")
# Out:
# hola

# %% [markdown]
# imprimir hello

# %%
import pandas as pd
from pathlib import Path
datos = pd.read_csv("movies.csv")
datos["MOVIES"]
# Out:
# 0                             Blood Red Sky
# 1       Masters of the Universe: Revelation
# 2                          The Walking Dead
# 3                            Rick and Morty
# 4                           Army of Thieves
#                        ...
# 9994                         The Imperfects
# 9995                                 Arcane
# 9996                      Heart of Invictus
# 9997                         The Imperfects
# 9998                         The Imperfects
# Name: MOVIES, Length: 9999, dtype: str

# %% [markdown]
# Selecciona las columnas "MOVIES" y "YEAR" (como DataFrame).

# %%
datos[["MOVIES", "YEAR"]]
# Out:
#                                    MOVIES         YEAR
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
# [9999 rows x 2 columns]

# %% [markdown]
# Saca las primeras 8 filas usando slicing estilo df[:8].

# %%
datos[:8]
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
# 5                          Outer Banks     (2020– )
# 6      The Last Letter from Your Lover       (2021)
# 7                               Dexter  (2006–2013)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
# 5          \nAction, Crime, Drama                 7.6
# 6                \nDrama, Romance                 6.8
# 7         \nCrime, Drama, Mystery                 8.6
#
# ...

# %% [markdown]
# Con .loc, selecciona las filas 0 a 4 (incluidas) y columnas "MOVIES" y "RATING".

# %%
datos.loc[0:4, ["MOVIES", "RATING"]]
# Out:
#                                 MOVIES  RATING
# 0                        Blood Red Sky     6.1
# 1  Masters of the Universe: Revelation     5.0
# 2                     The Walking Dead     8.2
# 3                       Rick and Morty     9.2
# 4                      Army of Thieves     NaN

# %% [markdown]
# Con .loc, selecciona las filas 20 a 30 (incluidas) y columnas "YEAR", "GENRE", "VOTES".

# %%
datos.loc[20:30, ["YEAR", "GENRE", "VOTES"]]
# Out:
#            YEAR                                       GENRE    VOTES
# 20       (2021)        \nDrama, Horror, Mystery               36,634
# 21  (1994–2004)               \nComedy, Romance              880,918
# 22     (2014– )      \nAction, Adventure, Drama              320,264
# 23     (2013– )                  \nCrime, Drama              393,414
# 24     (2021– )  \nAnimation, Action, Adventure                  NaN
# 25       (2021)       \nDrama, History, Romance                4,681
# 26  (2013–2020)      \nAction, Adventure, Drama              459,913
# 27     (2015– )                  \nCrime, Drama              347,857
# 28  (2005–2020)        \nDrama, Fantasy, Horror              404,273
# 29     (2013– )         \nCrime, Drama, Mystery              213,522
# 30       (2021)               \nHorror, Mystery               27,447

# %% [markdown]
# Con .iloc, selecciona filas 0 a 4 y las primeras 3 columnas (por posición).

# %%
datos.iloc[0:5, 0:3]
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE
# 0      \nAction, Horror, Thriller
# 1  \nAnimation, Action, Adventure
# 2       \nDrama, Horror, Thriller
# 3  \nAnimation, Adventure, Comedy
# 4         \nAction, Crime, Horror

# %%
datos[["MOVIES"]]
# Out:
#                                    MOVIES
# 0                           Blood Red Sky
# 1     Masters of the Universe: Revelation
# 2                        The Walking Dead
# 3                          Rick and Morty
# 4                         Army of Thieves
# ...                                   ...
# 9994                       The Imperfects
# 9995                               Arcane
# 9996                    Heart of Invictus
# 9997                       The Imperfects
# 9998                       The Imperfects
#
# [9999 rows x 1 columns]

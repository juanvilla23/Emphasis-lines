# %% [markdown]
# Filtra películas con RATING > 8 y guarda en df_r8.

# %%
import pandas as pd
datos = pd.read_csv("movies.csv")
df_r8 = datos[datos["RATING"] > 8]
df_r8
# Out:
#                   MOVIES         YEAR  \
# 2       The Walking Dead  (2010–2022)
# 3         Rick and Morty     (2013– )
# 7                 Dexter  (2006–2013)
# 11               Lucifer  (2016–2021)
# 16          Breaking Bad  (2008–2013)
# ...                  ...          ...
# 9918   Girl From Nowhere     (2018– )
# 9920   Girl From Nowhere     (2018– )
# 9922   Girl From Nowhere     (2018– )
# 9963         Castlevania  (2017–2021)
# 9979   Never Have I Ever     (2020– )
#
#                                            GENRE  RATING  \
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# 7            \nCrime, Drama, Mystery                 8.6
# 11           \nCrime, Drama, Fantasy                 8.1
# 16          \nCrime, Drama, Thriller                 9.4
# ...                                          ...     ...
# 9918         \nCrime, Drama, Fantasy                 8.3
# ...

# %% [markdown]
# Filtra películas con RATING >= 7 y muestra cuántas salen (shape[0]).

# %%
datos[datos["RATING"] >= 7].shape[0]
datos[datos["YEAR"]==2020].shape[0]
datos[datos["YEAR"]==2020]
datos.head(10)
datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   str
#  1   YEAR      9355 non-null   str
#  2   GENRE     9919 non-null   str
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   str
#  5   STARS     9999 non-null   str
#  6   VOTES     8179 non-null   str
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    str
# dtypes: float64(2), str(7)
# memory usage: 703.2 KB
